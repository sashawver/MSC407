# %% [markdown]
# <a name="top"></a>
#
# <div style="width:1000 px">
#
# <div style="float:right; width:300 px"><img src="https://github.com/brianmapes/ATM407/blob/master/images/LMT_5.4.png?raw=true" alt="Heating tendencies LMT_5.4 exercise image" style="height: 200px;"></div>
#
#
# <h1>Assignment 8: Heating rates in a midlatitude cyclone</h1>
# <h3>ATM 407, University of Miami</h3>
#
# * To use these Jupyter notebooks, you need to have installed all this:
# https://brianmapes.github.io/EarthCube-DRILSDOWN/ )
#
#
# ### Activities
# 1. <a href="#Exercise1">Some math about it</a>
# 1. <a href="#Exercise2">Load an IDV bundle</a>
# 1. <a href="#Exercise3">Answer the book's LMT_5.4 questions</a>
# 1. <a href="#Exercise4">Use LMT_5.4_MERRA_1979-2015 to make the same bundle for YOUR case.</a>
# 1. <a href="#Exercise5">Answer the mose interesting part for YOUR case.</a>
#
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">

# %% [markdown]
# ### Background
# Remember, for the test you will memorize and write the primitive equations:
# 1. Horizontal acceleration equation (F=ma):
# $$ \frac{d}{dt} \vec V_h = f \vec V_h \times \hat k  - \vec \nabla_p \Phi +\vec F_r  $$
# or, in component form,
# $$ \frac{du}{dt} = fv  - \frac{\partial \Phi}{\partial x} +F_{rx} $$
# $$ \frac{dv}{dt} = -fu - \frac{\partial \Phi}{\partial y} +F_{ry} $$
#
# 1. Vertical acceleration equation (aka Hydrostatic balance):
# $$ \frac {\partial \Phi}{\partial p} = - \alpha \equiv -\frac{1}{\rho} = \frac{RT}{p} = \frac{R\theta}{p} (\frac{T}{\theta})$$
# 1. Mass continuity:
# $$ 0 = \frac {\partial u}{\partial x} + \frac {\partial v}{\partial y}  + \frac {\partial \omega}{\partial p} $$
# 1. First Law of thermodynamics:
# $$ \frac {d \theta}{dt} = Q_\theta $$
# where $Q_\theta$, the heating rate in $\theta$ units, is related to dT/dt_{diabatic} = Q (in W/kg units) by:
# $$ Q_\theta = Q/C_p\frac{\theta}{T} $$
#
#
# #### For this exercise, let's focus on the First Law in the form used by atmosphere models (Eulerian grids).
#
# $$ \frac {\partial \theta}{\partial t} = -V \cdot \nabla \theta + Q_\theta  = Q_{dyn} + Q_{phys}$$
#
# Or, more to the point for digital atmospheric models with a finite timestep dt,
#
# $$ \theta_{future}(x,y,p) = \theta_{present} + dt \frac{(Q_{dyn} + Q_{phys} )} {C_p} \frac{\theta}{T}$$
#
# Save room in your brain for the concept of $Q_{ana}$, the *analysis tendency*, which is *the tendency required to make a model evolve in time as the world was observed to evolve in time.* (That is, *the sum of all errors in model estimates of Q{phys} and Q_{dyn} from all its derivatives and combinations of its state variables).
#
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise1"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 1</b>:
#      <ul>
#
# <li>**What is $\frac{\theta}{T}$ in the above casting of the equations? ** Show that it involves only the coordinate variable $p$.</li>
#
# <li>We can express $Q$ into the 3 physical forms of heat transfer (from fundamental physics): *radiation, conduction, convection, and chemical reaction.*</li>
#
# $$Q_{phys} = Q_{rad} +  Q_{surface} + Q_{turb} + Q_{chem}$$
#
# <li>**Explain in words how these map onto the column heating physics in atmosphere model:**</li>
#
# $$Q_{phys} = Q_{LW} +  Q_{SW} + Q_{SHF} + Q_{PBL \ diffusion} +Q_{gridscale \ cond-evap} + Q_{subgrid \ cumulus \ convection} +Q_{frictional \ dissipation}$$
#
# <li>**Explain how the profile of longwave radiation $Q_{LW}$ relates to the profile of cloudiness.**</li>
#
#     </ul>
# </div>

# %% [markdown]
# ## Exercise 1 Answer:
# ### First question bullet:
#
# $\frac{\theta}{T}$ =
#
#
# ### Second question (third bullet):
# 1. Q_LW is purely **radiative** (LW="longwave", the infrared radiation emitted by parts of the Earth system).
# 2. Q_SW is is purely **shortwave** (SW = "shortwave", the solar radiation emitted by the sun).
# 3. Q_SHF is **surface flux**
# 4. Q_PBL is purely **turbulent** (heat transfer from one altitude to another carried by small or "subgrid" parcels of air).
# 5. Q_cond is **condensation**
# 6. Q_cumulus is a mix of **water vapor (condensation)** and **latent heat release**
# 7. Q_friction is arguably a version of **"conduction"**, as the kinetic energy of the wind gets turned into heat by the **physical contact** of molecules from micro-airmasses with different velocities.
#
# ### Third question (fourth bullet):
#
# Longwave heaing Q_LW is positive where more infrared photons arrive than leave. It is negative wherever more IR photons leave than arrive. Cloud effects can be understood using the concept that solid surfaces (both the Earth and cloud top and bottom) absorb all photons that strike them (no reflection), and emit more or less according to their local temperature as $\sigma T^4$. Since temperature T decreases with height in the troposphere, ... (complete the paragraph logically) ...

# %% [markdown]
# <hr style="height:2px;">
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise2"></a>
# ## Exercise 2: Find and load the LMT_5.4 bundle. Capture the storm image.

# %% [markdown]
# <div class="alert alert-info">
#     <b>Note</b>:
#      (If you like, you could do the Sandy version I made yesterday as a test, but it is bigger and slower to load.)
# </div>

# %%
# %reload_ext drilsdown

# %%
# Your image 
# %makeImage
# Out:
# tempfile.tempdir = None
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise3"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 3</b>:
#      <ul>
#       <li>**Answer the LMT_5.4 questions a-k, using image captures and Markdown cells to make this notebook a readable document you are proud of.**
#
#       </li>
#
#        <li>To do this, **copy the boldface question for each part from the text**, and then write your answers in normal text, so that a reader of this notebook gets a coherent narrative.
#
#       </li>
#
#     </ul>
# </div>

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %% [markdown]
# ## Markdown answer for a):
# ** Are the position of the cyclone and its fronts fairly well analyzed in the model felds? Does the model’s rainfall (and condensation heating) match what you would infer from the satellite imagery? Capture an image indicating a discrepancy between the satellite observations and the model’s depiction of the storm. What is
# your assessment of the general quality of the analysis?**
#
# There is a cold from passing through the midlatitudes where the line of clouds can be seen on the satellite image as well as where the total precipitation is seen. The image where the IR satellite image and total precipitation totals are shown together demonstrates the discrepancy between the model depiction and satellite observations. The model depiction is pretty close to the satellite observations, but the model lags slightly behind the satellite observations. I would infer that there would be heavy rain seen around the area of clouds detected by the satellite image.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeMovie
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %% [markdown]
# ## Markdown answer for b):
# **Do some features in these displays correspond to each other? Which category of physical heating corresponds to MERRA’s prectot? What main diferences do you see in non-precipitating regions?**
#
# The physical information of dtheta/dt mathces up more closely with MERRA's prectot (Image 1). The phyiscal characteristics consist of condensation, convection, conduction, and radiation.

# %%
# %makeMovie
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# ## Markdown answer for c):
#
# The dynamic information is negative, while the physical term is positive. The negative advection suggests sinking motion (cold air advection), which overlaps with the MERRA total precipitation model. The adiabatic cooling balances out the release of latent heat from condensation.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeMovie
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %% [markdown]
# ## Markdown answer for d):
#
# The trough is located where there is a yellow arrow drawn and the negative phy+dyn is circled with the green arrow. phy+dyn is negative east of the trough, therefore resulting in the eastward propogation of the system. The negative portion of phy+dyn east of the trough also falls partially within the trough resulting in minor deepening of the system.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %% [markdown]
# ## Markdown answer for e):
#
# This field is very small in magnitude meaning there is not much error in the model.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %% [markdown]
# ## Markdown answer for f):
#
# The low and high clouds are located on the eastern side of the cyclone, while the middle clouds are located just above the center as well as on the eastern side. Usually the cloudiness appears on the eastern-northeastern side of cyclones, so this cross-section does aggree with the typical vertical structure of midlatitude cyclones.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %% [markdown]
# ## Markdown answer for g):
#
# There is positive shortwave radiation and mostly negative longwave radiation with a pocket of positive. The pocket of positive longwave radiation is in the lower clouds, which it would make sense that they would absorb more IR radiation from the surface, whereas high clouds would absorb more solar radiation. The approximate magnitude of heating in K per day is -0.864K/day for longwave radiation and for shortwave it is about 1.2K/day.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %% [markdown]
# ## Markdown answer for h):
#
# The turbulent and frictional heating terms are active at the surface. Both friction and turbulence are only seen very close to the surfae in the boundary layer.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %% [markdown]
# ## Markdown answer for i):
#
# The area's of highly saturated air matches the cloudiness field according to the cross-section. This area of moist air also corresponds to the MERRA precipitation model. There are negative values in the terms of moist processes downstream of the clouds, which could represent the outflow of the system.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %% [markdown]
# ## Markdown answer for j):
#
#
# You can see the turblent and fricitonal heating close to the surface and the large area of moist heating downstream of the center of the cyclone.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'
# tempfile.gettempdir() = '/var/folders/n_/lwh4zc29623c92vth4qctm2r0000gn/T'

# %% [markdown]
# ## Markdown answer for k):
#
# The heat budget in this midlatitude cyclone appears to be primarily adiabatic. The image above shows that the vertical integral over the column mass is mainly contributed by the lower troposphere.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise4"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 4</b>:
#      <ul>
#           <li>**Choose a storm case of your own. ** Maybe you did this last week. Choose carefully: you will revisit this as a project and perhaps make a Wikipedia page about it. If you like, choose a new one at this point.
#       </li>
#
#       <li>**Do the second optional exercise (loading LMT_5.4_MERRA_1979-2015 and moving the time and space box) for your case.**
#
#        <li>**Capture an image comparable to your favorite subsection above.**
#
#       </li>
#     </ul>
# </div>

# %%
# To use this feature, the IDV display must have its ID set to this name, in Properties. 
# %makeImage
# Out:
# ERROR:root:Line magic function `%makeImage` not found.

# %% [markdown]
# ## My case:
#
# #### I decided to study a storm that occurred (date and time, place), because (background info).
#
# The image above shows ...

# %%
# Wikipedia image
from IPython.display import Image
Image("an image URL goes here")

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# Upload your image to your GitHub area and put its URL into Blackboard.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">
